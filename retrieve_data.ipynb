# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime
## Load the NASA_API_KEY from the env file
load_dotenv()
NASA_API_KEY = os.getenv('NASA_API_KEY')

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
cme_url = f"{base_url}CME?StartDate={startDate}&EndDate={endDate}&api_key={NASA_API_KEY}"

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(cme_url)
cme_response
# Out:
# <Response [200]>

# %%
# Convert the response variable to json and store it as a variable named cme_json
cme_json = cme_response.json()

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(cme_json, indent=4))
# Out:
# [
#     {
#         "activityID": "2024-11-02T06:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-02T06:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint, narrow CME visible to the SW in SOHO LASCO C2/C3 and STEREO A COR2. There are potential source candidate eruptions seen on the disk in available EUV imagery, including a faint dimming seen in GOES SUVI 195/284 and STEREO A EUV 195 around S40W10 starting at 2024-11-02T05:00Z. Dimming and moving field lines can also be seen south of AR 3869 (approx. S20W50) starting at 2024-11-02T02:52Z. The eruption is not seen in SDO AIA imagery due to a data gap from approximately 2024-11-01T22:00Z to 2024-11-02T06:30Z.",
#         "submissionTime": "2024-11-02T15:51Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34372/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-02T15:56Z",
#                 "latitude": -49.0,
#                 "longitude": 26.0,
#                 "halfAngle": 20.0,
#                 "speed": 356.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.1,
#                 "submissionTime": "2024-11-02T15:52Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34373/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-02T17:31Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34376/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-02T06:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-02T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-02T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the west in SOHO LASCO C2/C3. The CME is not clearly visible in STEREO A COR2 white light imagery. The CME it not visible in SOHO LASCO C2/C3 after a data gap from 2024-11-02T10:24Z-13:25Z. There is also a data gap in STEREO A COR2 imagery from 2024-11-02T08:23Z-10:23Z. The source may be field line movement seen on the limb in STEREO A EUV 195 and GOES  SUVI 195 starting at 2024-11-02T05:35Z. A data gap was present in SDO AIA imagery from approx. 2024-11-01T22:00Z to 2024-11-02T06:30Z.",
#         "submissionTime": "2024-11-02T15:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34369/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-02T15:58Z",
#                 "latitude": 8.0,
#                 "longitude": 114.0,
#                 "halfAngle": 40.0,
#                 "speed": 514.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between one frame of available STEREO A COR2 imagery and SOHO LASCO C3 imagery in SWPC_CAT. SOHO LASCO C2 imagery was used for the majority of this measurement due to limited imagery availability.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2024-11-02T15:15Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34370/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-02T15:29Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34371/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-02T09:12:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-02T15:50Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34374/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Psyche",
#                                 "arrivalTime": "2024-11-10T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-02T09:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-03T13:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-03T13:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S12E85",
#         "activeRegionNum": null,
#         "note": "Narrow jet CME first seen in the east by SOHO LASCO C2 beginning at 2024-11-03T13:25Z as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. A possible source for this event is a minor eruption seen along the Eastern limb (approx. S12E85) in SDO AIA and GOES SUVI 304 beginning at approximately 2024-11-03T12:50Z.",
#         "submissionTime": "2024-11-04T14:19Z",
#         "versionId": 3,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34382/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-03T18:34Z",
#                 "latitude": -1.0,
#                 "longitude": -82.0,
#                 "halfAngle": 10.0,
#                 "speed": 662.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-03T17:12Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34383/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-03T17:23Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34384/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-06T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-03T13:25:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-03T15:27:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-03T15:27Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S10E53",
#         "activeRegionNum": 13883,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-03T15:27Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is an eruption and M1.1 flare from AR 3883 (S10E53) peaking at 03/15:18Z. Brightening and post eruptive arcades can be seen in SDO AIA 131, along with dimming and field line opening seen in SDO AIA 193.",
#         "submissionTime": "2024-11-03T18:10Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34387/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-03T21:25Z",
#                 "latitude": 4.0,
#                 "longitude": -68.0,
#                 "halfAngle": 29.0,
#                 "speed": 594.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-03T18:11Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34388/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-03T18:23Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34389/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T13:28Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-06T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-06T14:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T14:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-03T15:27:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-03T15:13:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T00:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T00:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely an eruption from Active Region 13877 (S17W44) starting at 2024-11-03T23:45Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the southwest limb in SDO AIA 171 and 193 at this time as well.",
#         "submissionTime": "2024-11-04T02:32Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34393/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T07:11Z",
#                 "latitude": -44.0,
#                 "longitude": 56.0,
#                 "halfAngle": 13.0,
#                 "speed": 497.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.2,
#                 "submissionTime": "2024-11-04T02:33Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34394/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-04T01:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T01:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S04E42",
#         "activeRegionNum": 13883,
#         "note": "Partial halo CME visible to the east in SOHO LASCO C2 and STEREO A COR2. The CME is visible in SOHO LASCO C3 after a data gap from 2024-11-04T02:18Z to 2024-11-04T05:43Z. The CME is associated with an M3.8 flare from AR 3883 (approximately S04E42) peaking at 2024-11-04T01:40Z. The eruption can be seen in all wavelengths of SDO AIA imagery, with brightening best seen in SDO AIA 131, dimming and EUV wave best seen in SDO AIA 193, and opening field lines best seen in SDO AIA 171. The eruption is also visible in STEREO A EUV imagery.",
#         "submissionTime": "2024-11-04T13:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34402/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T04:54Z",
#                 "latitude": 12.0,
#                 "longitude": -37.0,
#                 "halfAngle": 39.0,
#                 "speed": 1067.0,
#                 "type": "O",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of the bulk of the CME based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.5,
#                 "submissionTime": "2024-11-04T13:15Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34403/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-04T13:27Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-06T09:15Z",
#                         "estimatedDuration": 35.6,
#                         "rmin_re": 6.1,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34404/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-05T18:12Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T17:36Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T10:49Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-07T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T01:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-04T13:55Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-11-06T09:22Z",
#                         "estimatedDuration": 35.6,
#                         "rmin_re": 6.1,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34405/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-05T18:08Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T18:08Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T10:48Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-07T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T01:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T01:05:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-06T16:20:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T13:23:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T13:23Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S08W55",
#         "activeRegionNum": 13885,
#         "note": "CME visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2. The CME is not visible in STEREO A COR2 after a data gap starting at 2024-11-04T14:53Z. The potential source is a C6.6 flare peaking at 2024-11-04T11:55Z from AR 3885 (approximately S08W55) best seen in SDO AIA 131. Moving field lines and brightening can be seen in SDO AIA 171/193.",
#         "submissionTime": "2024-11-04T18:39Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34413/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T21:33Z",
#                 "latitude": -12.0,
#                 "longitude": 58.0,
#                 "halfAngle": 19.0,
#                 "speed": 377.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on source location as well as the best fit between SOHO LASCO C2/C3 and limited STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.1,
#                 "submissionTime": "2024-11-04T18:40Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34414/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-04T19:14Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34416/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-10T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T13:23:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T11:46:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T17:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T17:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S07E38",
#         "activeRegionNum": 13883,
#         "note": "CME seen to the E in all coronagraphs, with minimal frames in STEREO COR2A due to a data gap. This CME front is comprised of a slower northern piece and a faster southern piece which still relatively travel together, causing a distortion in the front as it travels from earliest frames -> later frames. The source is the double peaked M3.7 and M5.5 flare from AR 3883 (S07E38), which began at 2024-11-04T15:26Z in SDO AIA 131 with additional field line movement and very slight dimming observed in SDO AIA 171/193/211.",
#         "submissionTime": "2024-11-05T01:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34420/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T02:08Z",
#                 "latitude": 4.0,
#                 "longitude": -47.0,
#                 "halfAngle": 28.0,
#                 "speed": 388.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulated measurement using STEREO C2/C3 and STEREO COR2A, with notable difficulty using COR2A running difference imagery with only two available frames over the duration of this CME due to a data gap. The on-disk source flares observed in SDO AIA 131 also assisted in triangulating this event to this source, ruling out far-sided fits.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 19.0,
#                 "submissionTime": "2024-11-05T01:55Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34421/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T01:48Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-08T10:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34422/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-07T14:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T17:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T15:26:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-04T15:36:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-07T14:29:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T00:09:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T00:09Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N05E35",
#         "activeRegionNum": null,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-05T00:09Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is a region of dimming seen centered at approximately N05E35 beginning around 05/23:19Z as seen in SDO AIA 193 and 211. Field line opening is also visible in GOES SUVI 195 and 284.",
#         "submissionTime": "2024-11-05T14:27Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34428/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T06:13Z",
#                 "latitude": 6.0,
#                 "longitude": -36.0,
#                 "halfAngle": 23.0,
#                 "speed": 526.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T14:28Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34429/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T14:45Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-07T16:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34432/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-07T04:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-06T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T00:09:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-07T14:29:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T07:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T07:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S07E90",
#         "activeRegionNum": null,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-05T07:36Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is an M2.6 flare from the East limb (S07E90) peaking at 05/06:54Z as seen in SDO AIA 131. Field line opening is visible in SOS AIA 171, 193, 211, and GOES SUVI 284, along with post eruptive arcades seen in SDO AIA 94 and 131.",
#         "submissionTime": "2024-11-05T14:14Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34426/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T16:11Z",
#                 "latitude": -6.0,
#                 "longitude": -112.0,
#                 "halfAngle": 15.0,
#                 "speed": 388.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T14:16Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34427/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T14:28Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34431/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-08T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T07:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-05T06:35:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T12:38:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T12:38Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the east/southeast in STEREO A COR2 imagery and in SOHO LASCO C3 following a data gap lasting from 2024-11-05T10:42Z to 13:30Z. The source may be related to rising loops visible near the eastern limb starting around 2024-11-05T11:15Z as seen in SDO AIA 131, 171, and 193 imagery.",
#         "submissionTime": "2024-11-06T18:25Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34467/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T22:21Z",
#                 "latitude": -4.0,
#                 "longitude": -85.0,
#                 "halfAngle": 21.0,
#                 "speed": 338.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between STEREO A COR2 and SOHO LASCO C3 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.9,
#                 "submissionTime": "2024-11-06T18:26Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34468/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-06T18:38Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34469/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-08T08:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-09T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T12:38:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-05T13:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T13:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Very faint loop CME first seen in the West by SOHO LASCO C2 beginning at 2024-11-05T13:25Z, as well as in a few grainy frames of STEREO A COR2 in later imagery. There is no clear source seen for this CME, and a lack of triangulating coronagraph imagery makes determining a source location for this event difficult.",
#         "submissionTime": "2024-11-05T19:30Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34436/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T20:40Z",
#                 "latitude": 10.0,
#                 "longitude": null,
#                 "halfAngle": 40.0,
#                 "speed": 486.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "CME fits a range of longitudes (approx. 65 to 110 degrees). The lack of usable STEREO A COR2 imagery makes determining precise longitude difficult.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T19:32Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34437/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-05T16:09:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T16:09Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S15W90",
#         "activeRegionNum": null,
#         "note": "Wide CME visible to the west in STEREO A COR2 and after a data gap in SOHO LASCO C3 from 2024-11-05T14:30Z-23:54Z. The source is an M4.1 flare peaking at 2024-11-05T15:26Z (approx. S15W90) on or just beyond the west limb a seen in available EUV imagery. Opening field lines and EUV wave are also visible in SDO AIA 171/193.",
#         "submissionTime": "2024-11-06T16:03Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34458/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T22:27Z",
#                 "latitude": -19.0,
#                 "longitude": 90.0,
#                 "halfAngle": 43.0,
#                 "speed": 545.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "This measurement is more approximate than usual due to a large data gap in SOHO LASCO C3, and is based on limited available STEREO A COR2 and SOHO LASCO C3 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 29.0,
#                 "submissionTime": "2024-11-06T16:04Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34459/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-06T16:17Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34460/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-05T16:09:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-06T16:51Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34461/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Psyche",
#                                 "arrivalTime": "2024-11-13T00:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T16:09:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-05T15:05:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T23:28:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T23:28Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint CME visible to the southwest in SOHO LASCO C3 and STEREO A COR2. Not visible in SOHO LASCO C2 due to a data gap from 2024-11-05T14:30Z-23:54Z. The source is unclear, and the CME may be farsided.",
#         "submissionTime": "2024-11-06T17:29Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34463/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-06T06:45Z",
#                 "latitude": -19.0,
#                 "longitude": null,
#                 "halfAngle": 27.0,
#                 "speed": 444.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane of sky measurement using SOHO LASCO C3 difference imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.7,
#                 "submissionTime": "2024-11-06T17:30Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34464/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-06T06:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-06T06:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the NE in SOHO LASCO C2/C3 and faintly visible in STEREO A COR2. The potential source is likely on the far side, with opening field lines seen beyond the NE limb starting at 2024-11-06T05:18Z in SDO AIA 171/193. The field line movement is not clearly seen from the point of view of STEREO A EUV 195.",
#         "submissionTime": "2024-11-06T13:37Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34447/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-06T13:54Z",
#                 "latitude": 34.0,
#                 "longitude": -131.0,
#                 "halfAngle": 21.0,
#                 "speed": 414.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
# ...
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Slow, wide, outflow-like CME seen to the north in SOHO LASCO and to the west-northwest in STEREO A COR2. Likely associated with far-sided activity at high northern latitudes.",
#         "submissionTime": "2024-11-29T21:59Z",
#         "versionId": 2,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35394/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T00:13Z",
#                 "latitude": 66.0,
#                 "longitude": 180.0,
#                 "halfAngle": 36.0,
#                 "speed": 372.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading edge measurement encompassing all but the eastern most portion of the CME leading edge.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 17.0,
#                 "submissionTime": "2024-11-29T21:56Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35395/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-29T13:30:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-29T13:30Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S35E20",
#         "activeRegionNum": null,
#         "note": "Loop CME with internal filamentary structure seen due south in SOHO LASCO and STEREO A COR2; the source of this CME is likely the eruption of a SE hanging filament starting around 2024-11-29T12:00Z as seen in GOES SUVI 304, 284 and STA EUVI 195 and centered ~S35E20.",
#         "submissionTime": "2024-11-29T21:00Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35392/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-29T23:57Z",
#                 "latitude": -66.0,
#                 "longitude": 26.0,
#                 "halfAngle": 26.0,
#                 "speed": 404.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Leading edge/bulk measurement of the CME using SOHO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 15.0,
#                 "submissionTime": "2024-11-29T21:02Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35393/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-29T19:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-29T19:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S05E85",
#         "activeRegionNum": null,
#         "note": "Jet-like CME seen to the east-southeast in SOHO LASCO C2/C3; associated with a minor eruption near an equatorial active region near the eastern limb seen best in GOES SUVI 284 around 2024-11-2919:00Z.",
#         "submissionTime": "2024-11-29T22:51Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35396/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T00:24Z",
#                 "latitude": -13.0,
#                 "longitude": -87.0,
#                 "halfAngle": 10.0,
#                 "speed": 704.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "One spacecraft leading edge measurement approximating the source longitude based on EUV imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.0,
#                 "submissionTime": "2024-11-29T22:52Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35397/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-29T22:47Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35398/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-12-03T21:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-12-01T15:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-29T19:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-30T06:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-30T06:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the south/southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is an eruption visible near the southwest limb in GOES SUVI 304 imagery starting around 2024-11-30T05:30Z which exhibits a clear southern deflection.",
#         "submissionTime": "2024-11-30T15:49Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35405/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T11:30Z",
#                 "latitude": -71.0,
#                 "longitude": 90.0,
#                 "halfAngle": 14.0,
#                 "speed": 631.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measured longitude based on the approximate source location and best fit between SOHO LASCO C3 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.1,
#                 "submissionTime": "2024-11-30T15:51Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35406/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-30T11:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-30T11:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the east/southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely an eruption visible on/near the eastern limb in GOES SUVI 284 and 304 imagery starting around 2024-11-30T10:40Z. An opening of field lines is visible over the eastern limb at this time in GOES SUVI 171 and 195 imagery as well.",
#         "submissionTime": "2024-11-30T15:46Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35403/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T15:54Z",
#                 "latitude": -14.0,
#                 "longitude": -85.0,
#                 "halfAngle": 10.0,
#                 "speed": 749.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the approximate source location and best fit between SOHO LASCO C2 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.7,
#                 "submissionTime": "2024-11-30T15:48Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35404/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-30T15:52Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35407/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-12-02T10:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-30T11:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-12-01T03:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-12-01T03:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N20W70",
#         "activeRegionNum": null,
#         "note": "A CME to the west with the source a loop-like filament eruption seen in SUVI 304 starting after 02:16Z, with post-eruptive arcades and dimming seen in SUVI 284/195 and in EUVI A 195 centered very approximately at N20W40 in STA. The source is approximately at N20W70 in SUVI.",
#         "submissionTime": "2024-12-01T14:06Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35410/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-12-01T10:35Z",
#                 "latitude": -2.0,
#                 "longitude": 61.0,
#                 "halfAngle": 26.0,
#                 "speed": 467.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Analysis based on the fit with two coronagraphs.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-12-01T14:08Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35411/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-12-01T14:05Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35412/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-12-08T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-12-05T04:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-12-01T03:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-12-01T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-12-01T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Minor jet (or rather the first in a series of minor southward jets). The source has not been found and is possibly backsided.",
#         "submissionTime": "2024-12-01T16:17Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35413/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-12-01T18:22Z",
#                 "latitude": -71.0,
#                 "longitude": 175.0,
#                 "halfAngle": 12.0,
#                 "speed": 426.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Very approximate analysis based on the best fit with two coronagraphs.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-12-01T16:19Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35414/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %%
# Convert cme_json to a Pandas DataFrame 
df = pd.DataFrame(cme_json)
# Keep only the columns: activityID, startTime, linkedEvents
df=df[['activityID', 'startTime', 'linkedEvents']]
df.head()
# Out:
#                     activityID          startTime  \
# 0  2024-11-02T06:24:00-CME-001  2024-11-02T06:24Z
# 1  2024-11-02T09:12:00-CME-001  2024-11-02T09:12Z
# 2  2024-11-03T13:25:00-CME-001  2024-11-03T13:25Z
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 4  2024-11-04T00:24:00-CME-001  2024-11-04T00:24Z
#
#                                       linkedEvents
# 0                                             None
# 1                                             None
# 2                                             None
# 3  [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 4                                             None

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
df_cleaned = df.dropna()
df_cleaned.head()
# Out:
#                     activityID          startTime  \
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 5  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 6  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 7  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
# 8  2024-11-05T00:09:00-CME-001  2024-11-05T00:09Z
#
#                                         linkedEvents
# 3    [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 5  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 6    [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 7  [{'activityID': '2024-11-04T15:26:00-FLR-001'}...
# 8    [{'activityID': '2024-11-07T14:29:00-IPS-001'}]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
# and then iterates over the values in 'linkedEvents' 
# and adds the elements individually to a list of dictionaries where each row is one element 
# Initialize an empty list to store the expanded rows
# Iterate over each index in the DataFrame
# Create a new DataFrame from the expanded rows

expanded_rows = []
for index, row in df_cleaned.iterrows():
    activityID = row['activityID']
    startTime = row['startTime']
    linkedEvents = row['linkedEvents']
    for event in linkedEvents:
        expanded_rows.append({'activityID': activityID, 'startTime': startTime, 'linkedEvents': linkedEvents})
    
df_expanded = pd.DataFrame(expanded_rows)
print(df_expanded.head())
# Out:
#                     activityID          startTime  \
# 0  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 1  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 2  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 3  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 4  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
#
#                                         linkedEvents
# 0    [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 1  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 2  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 3    [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 4  [{'activityID': '2024-11-04T15:26:00-FLR-001'}...

# %%
# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents
# and verify below that it works as expected using one row from linkedEvents as an example
# Be sure to use a try and except block to handle errors
def extract_activityID_from_dict(input_dict):
        try:
                activityID = input_dict.get('activityID', None)
                return activityID
        except (ValueError, TypeError) as e:
        # Log the error or print it for debugging
                print(f"Error processing input dictionary: {input_dict}. Error: {e}")
        return None

example_row = df.loc[0, 'linkedEvents']
if example_row:
        activity_id =extract_activityID_from_dict(example_row[0])
        print(activity_id)
else:
        print("no linked events found in the example row.")

# Log the error or print it for debugging
print(activityID)
# Out:
# no linked events found in the example row.
# 2024-11-27T02:48:00-CME-001

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'GST_ActivityID' using loc indexer:
#print(df['linkedEvents'].head())
df.loc[:, 'GST_ActivityID'] = df['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x[0]) if isinstance (x, list) and len(x) > 0 else None)
print(df.head(10))
# Out:
#                     activityID          startTime  \
# 0  2024-11-02T06:24:00-CME-001  2024-11-02T06:24Z
# 1  2024-11-02T09:12:00-CME-001  2024-11-02T09:12Z
# 2  2024-11-03T13:25:00-CME-001  2024-11-03T13:25Z
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 4  2024-11-04T00:24:00-CME-001  2024-11-04T00:24Z
# 5  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 6  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 7  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
# 8  2024-11-05T00:09:00-CME-001  2024-11-05T00:09Z
# 9  2024-11-05T07:36:00-CME-001  2024-11-05T07:36Z
#
#                                         linkedEvents  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3    [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 4                                               None
# 5  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 6    [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 7  [{'activityID': '2024-11-04T15:26:00-FLR-001'}...
# 8    [{'activityID': '2024-11-07T14:29:00-IPS-001'}]
# 9    [{'activityID': '2024-11-05T06:35:00-FLR-001'}]
#
#                 GST_ActivityID
# 0                         None
# 1                         None
# 2                         None
# 3  2024-11-03T15:13:00-FLR-001
# 4                         None
# 5  2024-11-04T01:05:00-FLR-001
# 6  2024-11-04T11:46:00-FLR-001
# 7  2024-11-04T15:26:00-FLR-001
# 8  2024-11-07T14:29:00-IPS-001
# 9  2024-11-05T06:35:00-FLR-001

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:
df = df.dropna(subset=["GST_ActivityID"])
df.head()
# Out:
#                     activityID          startTime  \
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 5  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 6  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 7  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
# 8  2024-11-05T00:09:00-CME-001  2024-11-05T00:09Z
#
#                                         linkedEvents  \
# 3    [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 5  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 6    [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 7  [{'activityID': '2024-11-04T15:26:00-FLR-001'}...
# 8    [{'activityID': '2024-11-07T14:29:00-IPS-001'}]
#
#                 GST_ActivityID
# 3  2024-11-03T15:13:00-FLR-001
# 5  2024-11-04T01:05:00-FLR-001
# 6  2024-11-04T11:46:00-FLR-001
# 7  2024-11-04T15:26:00-FLR-001
# 8  2024-11-07T14:29:00-IPS-001

# %%
# print out the datatype of each column in this DataFrame:
print(df.dtypes)
# Out:
# activityID        object
# startTime         object
# linkedEvents      object
# GST_ActivityID    object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['activityID', 'startTime', 'linkedEvents', 'GST_ActivityID'], dtype='object')

# %%
# Convert the 'GST_ActivityID' column to string format 
df['GST_ActivityID'] = df['GST_ActivityID'].astype(str)
# Convert startTime to datetime format  
df['startTime'] = pd.to_datetime(df['startTime'])
# Rename startTime to startTime_CME and activityID to cmeID
df = df.rename(columns={'startTime':'startTime+cme','activityID':'cmeID'})
# Drop linkedEvents
df = df.drop(columns=['linkedEvents'])
# Verify that all steps were executed correctly
print(df.head())
# Out:
#                          cmeID             startTime+cme  \
# 3  2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 5  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 6  2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 7  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 8  2024-11-05T00:09:00-CME-001 2024-11-05 00:09:00+00:00
#
#                 GST_ActivityID
# 3  2024-11-03T15:13:00-FLR-001
# 5  2024-11-04T01:05:00-FLR-001
# 6  2024-11-04T11:46:00-FLR-001
# 7  2024-11-04T15:26:00-FLR-001
# 8  2024-11-07T14:29:00-IPS-001

# %%
print(df.columns)
if 'GST_ActivityID' in df.columns:
    print(df['GST_ActivityID'].head(10))
else:
    print("Column 'GST_ActivityID' not found in Data Frame")
# Out:
# Index(['cmeID', 'startTime+cme', 'GST_ActivityID'], dtype='object')
# 3     2024-11-03T15:13:00-FLR-001
# 5     2024-11-04T01:05:00-FLR-001
# 6     2024-11-04T11:46:00-FLR-001
# 7     2024-11-04T15:26:00-FLR-001
# 8     2024-11-07T14:29:00-IPS-001
# 9     2024-11-05T06:35:00-FLR-001
# 12    2024-11-05T15:05:00-FLR-001
# 17    2024-11-06T15:50:00-FLR-001
# 19    2024-11-06T23:10:00-FLR-001
# 33    2024-11-10T11:51:00-FLR-001
# Name: GST_ActivityID, dtype: object

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.  
df_filtered=df[df['GST_ActivityID'].str.contains('GST', na=False)]
print(f"Number of rows after filtering:{len(df_filtered)}")
print(df_filtered.head())
# Out:
# Number of rows after filtering:0
# Empty DataFrame
# Columns: [cmeID, startTime+cme, GST_ActivityID]
# Index: []

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for Geomagnetic Storms (GST):
GST = "GST"

# Search for GSTs between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST
gst_requests = f'{base_url}GST?StartDate={startDate}&EndDate={endDate}&api_key={NASA_API_KEY}'
gst_requests
# Out:
# 'https://api.nasa.gov/DONKI/GST?StartDate=2013-05-01&EndDate=2024-05-01&api_key=ludNWM2t3DZoKu7pHglwDRZslmnNHKa5FZHHTPyG'

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response
gst_response = requests.get(cme_url)
gst_response
# Out:
# <Response [200]>

# %%
# Convert the response variable to json and store it as a variable named gst_json

# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
gst_json = gst_response.json()
print(json.dumps(gst_json, indent=4))
# Out:
# [
#     {
#         "activityID": "2024-11-02T06:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-02T06:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint, narrow CME visible to the SW in SOHO LASCO C2/C3 and STEREO A COR2. There are potential source candidate eruptions seen on the disk in available EUV imagery, including a faint dimming seen in GOES SUVI 195/284 and STEREO A EUV 195 around S40W10 starting at 2024-11-02T05:00Z. Dimming and moving field lines can also be seen south of AR 3869 (approx. S20W50) starting at 2024-11-02T02:52Z. The eruption is not seen in SDO AIA imagery due to a data gap from approximately 2024-11-01T22:00Z to 2024-11-02T06:30Z.",
#         "submissionTime": "2024-11-02T15:51Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34372/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-02T15:56Z",
#                 "latitude": -49.0,
#                 "longitude": 26.0,
#                 "halfAngle": 20.0,
#                 "speed": 356.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.1,
#                 "submissionTime": "2024-11-02T15:52Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34373/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-02T17:31Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34376/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-02T06:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-02T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-02T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the west in SOHO LASCO C2/C3. The CME is not clearly visible in STEREO A COR2 white light imagery. The CME it not visible in SOHO LASCO C2/C3 after a data gap from 2024-11-02T10:24Z-13:25Z. There is also a data gap in STEREO A COR2 imagery from 2024-11-02T08:23Z-10:23Z. The source may be field line movement seen on the limb in STEREO A EUV 195 and GOES  SUVI 195 starting at 2024-11-02T05:35Z. A data gap was present in SDO AIA imagery from approx. 2024-11-01T22:00Z to 2024-11-02T06:30Z.",
#         "submissionTime": "2024-11-02T15:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34369/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-02T15:58Z",
#                 "latitude": 8.0,
#                 "longitude": 114.0,
#                 "halfAngle": 40.0,
#                 "speed": 514.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between one frame of available STEREO A COR2 imagery and SOHO LASCO C3 imagery in SWPC_CAT. SOHO LASCO C2 imagery was used for the majority of this measurement due to limited imagery availability.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.0,
#                 "submissionTime": "2024-11-02T15:15Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34370/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-02T15:29Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34371/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-02T09:12:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-02T15:50Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34374/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Psyche",
#                                 "arrivalTime": "2024-11-10T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-02T09:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-03T13:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-03T13:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S12E85",
#         "activeRegionNum": null,
#         "note": "Narrow jet CME first seen in the east by SOHO LASCO C2 beginning at 2024-11-03T13:25Z as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. A possible source for this event is a minor eruption seen along the Eastern limb (approx. S12E85) in SDO AIA and GOES SUVI 304 beginning at approximately 2024-11-03T12:50Z.",
#         "submissionTime": "2024-11-04T14:19Z",
#         "versionId": 3,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34382/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-03T18:34Z",
#                 "latitude": -1.0,
#                 "longitude": -82.0,
#                 "halfAngle": 10.0,
#                 "speed": 662.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-03T17:12Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34383/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-03T17:23Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34384/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-06T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-03T13:25:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-03T15:27:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-03T15:27Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S10E53",
#         "activeRegionNum": 13883,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-03T15:27Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is an eruption and M1.1 flare from AR 3883 (S10E53) peaking at 03/15:18Z. Brightening and post eruptive arcades can be seen in SDO AIA 131, along with dimming and field line opening seen in SDO AIA 193.",
#         "submissionTime": "2024-11-03T18:10Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34387/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-03T21:25Z",
#                 "latitude": 4.0,
#                 "longitude": -68.0,
#                 "halfAngle": 29.0,
#                 "speed": 594.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-03T18:11Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34388/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-03T18:23Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34389/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T13:28Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-06T00:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-06T14:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T14:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-03T15:27:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-03T15:13:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T00:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T00:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely an eruption from Active Region 13877 (S17W44) starting at 2024-11-03T23:45Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the southwest limb in SDO AIA 171 and 193 at this time as well.",
#         "submissionTime": "2024-11-04T02:32Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34393/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T07:11Z",
#                 "latitude": -44.0,
#                 "longitude": 56.0,
#                 "halfAngle": 13.0,
#                 "speed": 497.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between SOHO LASCO C2 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 8.2,
#                 "submissionTime": "2024-11-04T02:33Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34394/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-04T01:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T01:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S04E42",
#         "activeRegionNum": 13883,
#         "note": "Partial halo CME visible to the east in SOHO LASCO C2 and STEREO A COR2. The CME is visible in SOHO LASCO C3 after a data gap from 2024-11-04T02:18Z to 2024-11-04T05:43Z. The CME is associated with an M3.8 flare from AR 3883 (approximately S04E42) peaking at 2024-11-04T01:40Z. The eruption can be seen in all wavelengths of SDO AIA imagery, with brightening best seen in SDO AIA 131, dimming and EUV wave best seen in SDO AIA 193, and opening field lines best seen in SDO AIA 171. The eruption is also visible in STEREO A EUV imagery.",
#         "submissionTime": "2024-11-04T13:13Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34402/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T04:54Z",
#                 "latitude": 12.0,
#                 "longitude": -37.0,
#                 "halfAngle": 39.0,
#                 "speed": 1067.0,
#                 "type": "O",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement of the bulk of the CME based on the best fit between SOHO LASCO C2/C3 and STEREO A COR2 imagery in SWPC_CAT",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 14.5,
#                 "submissionTime": "2024-11-04T13:15Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34403/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-04T13:27Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-06T09:15Z",
#                         "estimatedDuration": 35.6,
#                         "rmin_re": 6.1,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34404/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-05T18:12Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T17:36Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T10:49Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-07T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T01:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-04T13:55Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": "2024-11-06T09:22Z",
#                         "estimatedDuration": 35.6,
#                         "rmin_re": 6.1,
#                         "kp_18": null,
#                         "kp_90": 4,
#                         "kp_135": 6,
#                         "kp_180": 7,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34405/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-05T18:08Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-05T18:08Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-05T10:48Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-11-07T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T01:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T01:05:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-06T16:20:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T13:23:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T13:23Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S08W55",
#         "activeRegionNum": 13885,
#         "note": "CME visible to the southwest in SOHO LASCO C2/C3 and STEREO A COR2. The CME is not visible in STEREO A COR2 after a data gap starting at 2024-11-04T14:53Z. The potential source is a C6.6 flare peaking at 2024-11-04T11:55Z from AR 3885 (approximately S08W55) best seen in SDO AIA 131. Moving field lines and brightening can be seen in SDO AIA 171/193.",
#         "submissionTime": "2024-11-04T18:39Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34413/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-04T21:33Z",
#                 "latitude": -12.0,
#                 "longitude": 58.0,
#                 "halfAngle": 19.0,
#                 "speed": 377.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on source location as well as the best fit between SOHO LASCO C2/C3 and limited STEREO A COR2 imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.1,
#                 "submissionTime": "2024-11-04T18:40Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34414/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-04T19:14Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34416/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-11-10T08:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T13:23:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T11:46:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-04T17:24:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-04T17:24Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S07E38",
#         "activeRegionNum": 13883,
#         "note": "CME seen to the E in all coronagraphs, with minimal frames in STEREO COR2A due to a data gap. This CME front is comprised of a slower northern piece and a faster southern piece which still relatively travel together, causing a distortion in the front as it travels from earliest frames -> later frames. The source is the double peaked M3.7 and M5.5 flare from AR 3883 (S07E38), which began at 2024-11-04T15:26Z in SDO AIA 131 with additional field line movement and very slight dimming observed in SDO AIA 171/193/211.",
#         "submissionTime": "2024-11-05T01:53Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34420/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T02:08Z",
#                 "latitude": 4.0,
#                 "longitude": -47.0,
#                 "halfAngle": 28.0,
#                 "speed": 388.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Triangulated measurement using STEREO C2/C3 and STEREO COR2A, with notable difficulty using COR2A running difference imagery with only two available frames over the duration of this CME due to a data gap. The on-disk source flares observed in SDO AIA 131 also assisted in triangulating this event to this source, ruling out far-sided fits.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 19.0,
#                 "submissionTime": "2024-11-05T01:55Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34421/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T01:48Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-08T10:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34422/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-07T14:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-04T17:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-04T15:26:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-04T15:36:00-FLR-001"
#             },
#             {
#                 "activityID": "2024-11-07T14:29:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T00:09:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T00:09Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N05E35",
#         "activeRegionNum": null,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-05T00:09Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is a region of dimming seen centered at approximately N05E35 beginning around 05/23:19Z as seen in SDO AIA 193 and 211. Field line opening is also visible in GOES SUVI 195 and 284.",
#         "submissionTime": "2024-11-05T14:27Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34428/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T06:13Z",
#                 "latitude": 6.0,
#                 "longitude": -36.0,
#                 "halfAngle": 23.0,
#                 "speed": 526.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T14:28Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34429/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T14:45Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2024-11-07T16:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": 3,
#                         "kp_135": 5,
#                         "kp_180": 5,
#                         "isEarthGB": true,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34432/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Lucy",
#                                 "arrivalTime": "2024-11-07T04:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Solar Orbiter",
#                                 "arrivalTime": "2024-11-06T20:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T00:09:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-07T14:29:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T07:36:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T07:36Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S07E90",
#         "activeRegionNum": null,
#         "note": "CME first seen in the East by SOHO LASCO C2 beginning at 2024-11-05T07:36Z, as well as by SOHO LASCO C3 and STEREO A COR2 in later frames. The source of this event is an M2.6 flare from the East limb (S07E90) peaking at 05/06:54Z as seen in SDO AIA 131. Field line opening is visible in SOS AIA 171, 193, 211, and GOES SUVI 284, along with post eruptive arcades seen in SDO AIA 94 and 131.",
#         "submissionTime": "2024-11-05T14:14Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34426/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T16:11Z",
#                 "latitude": -6.0,
#                 "longitude": -112.0,
#                 "halfAngle": 15.0,
#                 "speed": 388.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on approximate source location and best fit between SOHO LASCO C2/C3 and STEREO A COR2",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T14:16Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34427/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-05T14:28Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34431/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-08T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-07T18:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T07:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-05T06:35:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T12:38:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T12:38Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the east/southeast in STEREO A COR2 imagery and in SOHO LASCO C3 following a data gap lasting from 2024-11-05T10:42Z to 13:30Z. The source may be related to rising loops visible near the eastern limb starting around 2024-11-05T11:15Z as seen in SDO AIA 131, 171, and 193 imagery.",
#         "submissionTime": "2024-11-06T18:25Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34467/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T22:21Z",
#                 "latitude": -4.0,
#                 "longitude": -85.0,
#                 "halfAngle": 21.0,
#                 "speed": 338.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the best fit between STEREO A COR2 and SOHO LASCO C3 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 7.9,
#                 "submissionTime": "2024-11-06T18:26Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34468/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-06T18:38Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34469/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-11-08T08:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-11-09T02:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T12:38:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-05T13:25:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T13:25Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Very faint loop CME first seen in the West by SOHO LASCO C2 beginning at 2024-11-05T13:25Z, as well as in a few grainy frames of STEREO A COR2 in later imagery. There is no clear source seen for this CME, and a lack of triangulating coronagraph imagery makes determining a source location for this event difficult.",
#         "submissionTime": "2024-11-05T19:30Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34436/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T20:40Z",
#                 "latitude": 10.0,
#                 "longitude": null,
#                 "halfAngle": 40.0,
#                 "speed": 486.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "CME fits a range of longitudes (approx. 65 to 110 degrees). The lack of usable STEREO A COR2 imagery makes determining precise longitude difficult.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-11-05T19:32Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34437/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-05T16:09:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T16:09Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "S15W90",
#         "activeRegionNum": null,
#         "note": "Wide CME visible to the west in STEREO A COR2 and after a data gap in SOHO LASCO C3 from 2024-11-05T14:30Z-23:54Z. The source is an M4.1 flare peaking at 2024-11-05T15:26Z (approx. S15W90) on or just beyond the west limb a seen in available EUV imagery. Opening field lines and EUV wave are also visible in SDO AIA 171/193.",
#         "submissionTime": "2024-11-06T16:03Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34458/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-05T22:27Z",
#                 "latitude": -19.0,
#                 "longitude": 90.0,
#                 "halfAngle": 43.0,
#                 "speed": 545.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "This measurement is more approximate than usual due to a large data gap in SOHO LASCO C3, and is based on limited available STEREO A COR2 and SOHO LASCO C3 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 29.0,
#                 "submissionTime": "2024-11-06T16:04Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34459/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-06T16:17Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34460/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2024-11-05T16:09:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2024-11-06T16:51Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/34461/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Psyche",
#                                 "arrivalTime": "2024-11-13T00:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-05T16:09:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2024-11-05T15:05:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2024-11-05T23:28:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-05T23:28Z",
#         "instruments": [
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Faint CME visible to the southwest in SOHO LASCO C3 and STEREO A COR2. Not visible in SOHO LASCO C2 due to a data gap from 2024-11-05T14:30Z-23:54Z. The source is unclear, and the CME may be farsided.",
#         "submissionTime": "2024-11-06T17:29Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34463/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-06T06:45Z",
#                 "latitude": -19.0,
#                 "longitude": null,
#                 "halfAngle": 27.0,
#                 "speed": 444.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "Plane-of-sky",
#                 "note": "Plane of sky measurement using SOHO LASCO C3 difference imagery in SWPC_CAT.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 10.7,
#                 "submissionTime": "2024-11-06T17:30Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/34464/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-06T06:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-06T06:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "CME visible to the NE in SOHO LASCO C2/C3 and faintly visible in STEREO A COR2. The potential source is likely on the far side, with opening field lines seen beyond the NE limb starting at 2024-11-06T05:18Z in SDO AIA 171/193. The field line movement is not clearly seen from the point of view of STEREO A EUV 195.",
#         "submissionTime": "2024-11-06T13:37Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/34447/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-06T13:54Z",
#                 "latitude": 34.0,
#                 "longitude": -131.0,
#                 "halfAngle": 21.0,
#                 "speed": 414.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
# ...
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Slow, wide, outflow-like CME seen to the north in SOHO LASCO and to the west-northwest in STEREO A COR2. Likely associated with far-sided activity at high northern latitudes.",
#         "submissionTime": "2024-11-29T21:59Z",
#         "versionId": 2,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35394/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T00:13Z",
#                 "latitude": 66.0,
#                 "longitude": 180.0,
#                 "halfAngle": 36.0,
#                 "speed": 372.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Two spacecraft leading edge measurement encompassing all but the eastern most portion of the CME leading edge.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 17.0,
#                 "submissionTime": "2024-11-29T21:56Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35395/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-29T13:30:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-29T13:30Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S35E20",
#         "activeRegionNum": null,
#         "note": "Loop CME with internal filamentary structure seen due south in SOHO LASCO and STEREO A COR2; the source of this CME is likely the eruption of a SE hanging filament starting around 2024-11-29T12:00Z as seen in GOES SUVI 304, 284 and STA EUVI 195 and centered ~S35E20.",
#         "submissionTime": "2024-11-29T21:00Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35392/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-29T23:57Z",
#                 "latitude": -66.0,
#                 "longitude": 26.0,
#                 "halfAngle": 26.0,
#                 "speed": 404.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Leading edge/bulk measurement of the CME using SOHO C2/C3 and STEREO A COR2.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 15.0,
#                 "submissionTime": "2024-11-29T21:02Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35393/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-29T19:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-29T19:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "S05E85",
#         "activeRegionNum": null,
#         "note": "Jet-like CME seen to the east-southeast in SOHO LASCO C2/C3; associated with a minor eruption near an equatorial active region near the eastern limb seen best in GOES SUVI 284 around 2024-11-2919:00Z.",
#         "submissionTime": "2024-11-29T22:51Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35396/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T00:24Z",
#                 "latitude": -13.0,
#                 "longitude": -87.0,
#                 "halfAngle": 10.0,
#                 "speed": 704.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "One spacecraft leading edge measurement approximating the source longitude based on EUV imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 9.0,
#                 "submissionTime": "2024-11-29T22:52Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35397/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-29T22:47Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35398/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "OSIRIS-APEX",
#                                 "arrivalTime": "2024-12-03T21:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-12-01T15:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-29T19:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-30T06:00:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-30T06:00Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the south/southwest in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is an eruption visible near the southwest limb in GOES SUVI 304 imagery starting around 2024-11-30T05:30Z which exhibits a clear southern deflection.",
#         "submissionTime": "2024-11-30T15:49Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35405/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T11:30Z",
#                 "latitude": -71.0,
#                 "longitude": 90.0,
#                 "halfAngle": 14.0,
#                 "speed": 631.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measured longitude based on the approximate source location and best fit between SOHO LASCO C3 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 12.1,
#                 "submissionTime": "2024-11-30T15:51Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35406/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-11-30T11:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-11-30T11:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "This CME is visible to the east/southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely an eruption visible on/near the eastern limb in GOES SUVI 284 and 304 imagery starting around 2024-11-30T10:40Z. An opening of field lines is visible over the eastern limb at this time in GOES SUVI 171 and 195 imagery as well.",
#         "submissionTime": "2024-11-30T15:46Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35403/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-11-30T15:54Z",
#                 "latitude": -14.0,
#                 "longitude": -85.0,
#                 "halfAngle": 10.0,
#                 "speed": 749.0,
#                 "type": "C",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Measurement based on the approximate source location and best fit between SOHO LASCO C2 and STEREO A COR2 imagery.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": 11.7,
#                 "submissionTime": "2024-11-30T15:48Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35404/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-11-30T15:52Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35407/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Parker Solar Probe",
#                                 "arrivalTime": "2024-12-02T10:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-11-30T11:12:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-12-01T03:48:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-12-01T03:48Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "N20W70",
#         "activeRegionNum": null,
#         "note": "A CME to the west with the source a loop-like filament eruption seen in SUVI 304 starting after 02:16Z, with post-eruptive arcades and dimming seen in SUVI 284/195 and in EUVI A 195 centered very approximately at N20W40 in STA. The source is approximately at N20W70 in SUVI.",
#         "submissionTime": "2024-12-01T14:06Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35410/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-12-01T10:35Z",
#                 "latitude": -2.0,
#                 "longitude": 61.0,
#                 "halfAngle": 26.0,
#                 "speed": 467.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Analysis based on the fit with two coronagraphs.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-12-01T14:08Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35411/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2024-12-01T14:05Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/35412/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Mars",
#                                 "arrivalTime": "2024-12-08T16:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2024-12-05T04:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2024-12-01T03:48:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2024-12-01T09:12:00-CME-001",
#         "catalog": "M2M_CATALOG",
#         "startTime": "2024-12-01T09:12Z",
#         "instruments": [
#             {
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "note": "Minor jet (or rather the first in a series of minor southward jets). The source has not been found and is possibly backsided.",
#         "submissionTime": "2024-12-01T16:17Z",
#         "versionId": 1,
#         "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/35413/-1",
#         "cmeAnalyses": [
#             {
#                 "isMostAccurate": true,
#                 "time21_5": "2024-12-01T18:22Z",
#                 "latitude": -71.0,
#                 "longitude": 175.0,
#                 "halfAngle": 12.0,
#                 "speed": 426.0,
#                 "type": "S",
#                 "featureCode": "LE",
#                 "imageType": "running difference",
#                 "measurementTechnique": "SWPC_CAT",
#                 "note": "Very approximate analysis based on the best fit with two coronagraphs.",
#                 "levelOfData": 0,
#                 "tilt": null,
#                 "minorHalfWidth": null,
#                 "speedMeasuredAtHeight": null,
#                 "submissionTime": "2024-12-01T16:19Z",
#                 "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/35414/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %%
# Convert gst_json to a Pandas DataFrame  

# Keep only the columns: activityID, startTime, linkedEvents
gst_df = pd.DataFrame(gst_json)
gst_df

gst_df= gst_df[['activityID', 'startTime', 'linkedEvents']]
gst_df.head()
# Out:
#                     activityID          startTime  \
# 0  2024-11-02T06:24:00-CME-001  2024-11-02T06:24Z
# 1  2024-11-02T09:12:00-CME-001  2024-11-02T09:12Z
# 2  2024-11-03T13:25:00-CME-001  2024-11-03T13:25Z
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 4  2024-11-04T00:24:00-CME-001  2024-11-04T00:24Z
#
#                                       linkedEvents
# 0                                             None
# 1                                             None
# 2                                             None
# 3  [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 4                                             None

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME
gst_df = gst_df.dropna(subset=["linkedEvents"])
gst_df.head()
# Out:
#                     activityID          startTime  \
# 3  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 5  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 6  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 7  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
# 8  2024-11-05T00:09:00-CME-001  2024-11-05T00:09Z
#
#                                         linkedEvents
# 3    [{'activityID': '2024-11-03T15:13:00-FLR-001'}]
# 5  [{'activityID': '2024-11-04T01:05:00-FLR-001'}...
# 6    [{'activityID': '2024-11-04T11:46:00-FLR-001'}]
# 7  [{'activityID': '2024-11-04T15:26:00-FLR-001'}...
# 8    [{'activityID': '2024-11-07T14:29:00-IPS-001'}]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.
df_explode = gst_df.explode('linkedEvents', ignore_index=True).dropna()
df_explode.head()
# Out:
#                     activityID          startTime  \
# 0  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 1  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 2  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 3  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 4  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
#
#                                     linkedEvents
# 0  {'activityID': '2024-11-03T15:13:00-FLR-001'}
# 1  {'activityID': '2024-11-04T01:05:00-FLR-001'}
# 2  {'activityID': '2024-11-06T16:20:00-IPS-001'}
# 3  {'activityID': '2024-11-04T11:46:00-FLR-001'}
# 4  {'activityID': '2024-11-04T15:26:00-FLR-001'}

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'CME_ActivityID' using loc indexer:

df_explode.loc[:, "CME_ActivityID"] = df_explode['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x))

# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:
df_explode = df_explode.dropna(subset=['CME_ActivityID'])
print(df_explode.head())
# Out:
#                     activityID          startTime  \
# 0  2024-11-03T15:27:00-CME-001  2024-11-03T15:27Z
# 1  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 2  2024-11-04T01:36:00-CME-001  2024-11-04T01:36Z
# 3  2024-11-04T13:23:00-CME-001  2024-11-04T13:23Z
# 4  2024-11-04T17:24:00-CME-001  2024-11-04T17:24Z
#
#                                     linkedEvents               CME_ActivityID
# 0  {'activityID': '2024-11-03T15:13:00-FLR-001'}  2024-11-03T15:13:00-FLR-001
# 1  {'activityID': '2024-11-04T01:05:00-FLR-001'}  2024-11-04T01:05:00-FLR-001
# 2  {'activityID': '2024-11-06T16:20:00-IPS-001'}  2024-11-06T16:20:00-IPS-001
# 3  {'activityID': '2024-11-04T11:46:00-FLR-001'}  2024-11-04T11:46:00-FLR-001
# 4  {'activityID': '2024-11-04T15:26:00-FLR-001'}  2024-11-04T15:26:00-FLR-001

# %%
df_explode.columns
# Out:
# Index(['activityID', 'startTime', 'linkedEvents', 'CME_ActivityID'], dtype='object')

# %%
# Convert the 'CME_ActivityID' column to string format 
#df_explode = df_explode['CME_ActivityID'].astype(str)
df_explode['CME_ActivityID'] = df_explode['CME_ActivityID'].astype(str)

# Convert the 'gstID' column to string format 
#df_explode['activityID'].astype(str)
df_explode['activityID'] = df_explode['activityID'].astype(str)
# Convert startTime to datetime format  
df_explode['startTime'] = pd.to_datetime(df_explode['startTime'])
# Rename startTime to startTime_GST 
df_explode = df_explode.rename(columns={'startTime':'startTime+GST'})
# Drop linkedEvents
df_explode.drop(columns=['linkedEvents'], inplace=True)
# Verify that all steps were executed correctly
print(df_explode.head())
# Out:
#                     activityID             startTime+GST  \
# 0  2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 1  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 2  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 3  2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 4  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
#
#                 CME_ActivityID
# 0  2024-11-03T15:13:00-FLR-001
# 1  2024-11-04T01:05:00-FLR-001
# 2  2024-11-06T16:20:00-IPS-001
# 3  2024-11-04T11:46:00-FLR-001
# 4  2024-11-04T15:26:00-FLR-001

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.  

df_explode = df_explode[df_explode['activityID'].str.contains('CME', na=False)]
print(df_explode)
# Out:
#                      activityID             startTime+GST  \
# 0   2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 1   2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 2   2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 3   2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 4   2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 5   2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 6   2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 7   2024-11-05T00:09:00-CME-001 2024-11-05 00:09:00+00:00
# 8   2024-11-05T07:36:00-CME-001 2024-11-05 07:36:00+00:00
# 9   2024-11-05T16:09:00-CME-001 2024-11-05 16:09:00+00:00
# 10  2024-11-06T16:48:00-CME-001 2024-11-06 16:48:00+00:00
# 11  2024-11-06T23:36:00-CME-001 2024-11-06 23:36:00+00:00
# 12  2024-11-10T12:36:00-CME-001 2024-11-10 12:36:00+00:00
# 13  2024-11-10T17:12:00-CME-001 2024-11-10 17:12:00+00:00
# 14  2024-11-10T23:09:00-CME-001 2024-11-10 23:09:00+00:00
# 15  2024-11-11T01:23:00-CME-001 2024-11-11 01:23:00+00:00
# 16  2024-11-12T13:36:00-CME-001 2024-11-12 13:36:00+00:00
# 17  2024-11-15T02:48:00-CME-001 2024-11-15 02:48:00+00:00
# 18  2024-11-17T11:24:00-CME-001 2024-11-17 11:24:00+00:00
# 19  2024-11-18T12:12:00-CME-001 2024-11-18 12:12:00+00:00
# 20  2024-11-18T12:12:00-CME-001 2024-11-18 12:12:00+00:00
# 21  2024-11-18T19:24:00-CME-001 2024-11-18 19:24:00+00:00
# 22  2024-11-20T20:00:00-CME-001 2024-11-20 20:00:00+00:00
# 23  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 24  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 25  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 26  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 27  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 28  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 29  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 30  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 31  2024-11-21T18:12:00-CME-001 2024-11-21 18:12:00+00:00
# 32  2024-11-22T22:12:00-CME-001 2024-11-22 22:12:00+00:00
# 33  2024-11-23T19:24:00-CME-001 2024-11-23 19:24:00+00:00
# 34  2024-11-25T03:12:00-CME-001 2024-11-25 03:12:00+00:00
# 35  2024-11-25T03:12:00-CME-001 2024-11-25 03:12:00+00:00
# 36  2024-11-25T04:00:00-CME-001 2024-11-25 04:00:00+00:00
# 37  2024-11-25T04:00:00-CME-001 2024-11-25 04:00:00+00:00
# 38  2024-11-25T21:24:00-CME-001 2024-11-25 21:24:00+00:00
# 39  2024-11-25T21:24:00-CME-001 2024-11-25 21:24:00+00:00
# 40  2024-11-25T21:24:00-CME-001 2024-11-25 21:24:00+00:00
# 41  2024-11-27T02:48:00-CME-001 2024-11-27 02:48:00+00:00
#
#                  CME_ActivityID
# 0   2024-11-03T15:13:00-FLR-001
# 1   2024-11-04T01:05:00-FLR-001
# 2   2024-11-06T16:20:00-IPS-001
# 3   2024-11-04T11:46:00-FLR-001
# 4   2024-11-04T15:26:00-FLR-001
# 5   2024-11-04T15:36:00-FLR-001
# 6   2024-11-07T14:29:00-IPS-001
# 7   2024-11-07T14:29:00-IPS-001
# 8   2024-11-05T06:35:00-FLR-001
# 9   2024-11-05T15:05:00-FLR-001
# 10  2024-11-06T15:50:00-FLR-001
# 11  2024-11-06T23:10:00-FLR-001
# 12  2024-11-10T11:51:00-FLR-001
# 13  2024-11-10T15:51:00-FLR-001
# 14  2024-11-10T22:31:00-FLR-001
# 15  2024-11-14T03:32:00-IPS-001
# 16  2024-11-12T12:47:00-FLR-001
# 17  2024-11-15T01:38:00-FLR-001
# 18  2024-11-17T10:38:00-FLR-001
# 19  2024-11-18T11:06:00-FLR-001
# 20  2024-11-22T00:47:00-IPS-001
# 21  2024-11-18T18:45:00-FLR-001
# 22  2024-11-20T19:11:00-FLR-001
# 23  2024-11-21T18:45:00-SEP-001
# 24  2024-11-21T19:10:00-SEP-001
# 25  2024-11-21T19:19:00-SEP-001
# 26  2024-11-21T19:21:00-SEP-001
# 27  2024-11-21T19:23:00-SEP-002
# 28  2024-11-21T19:23:00-SEP-001
# 29  2024-11-21T19:24:00-SEP-001
# 30  2024-11-21T19:24:00-SEP-002
# 31  2024-11-21T19:25:00-SEP-001
# 32  2024-11-22T21:26:00-FLR-001
# 33  2024-11-23T19:01:00-FLR-001
# 34  2024-11-29T00:40:00-IPS-001
# 35  2024-11-29T02:15:00-IPS-001
# 36  2024-11-29T00:40:00-IPS-001
# 37  2024-11-29T02:15:00-IPS-001
# 38  2024-11-25T20:24:00-FLR-001
# 39  2024-11-29T00:40:00-IPS-001
# 40  2024-11-29T02:15:00-IPS-001
# 41  2024-11-27T02:21:00-FLR-001

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID'/activityID and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.
merged_df = pd.merge(df_explode, df, left_on=['CME_ActivityID', 'activityID'], right_on=['GST_ActivityID','cmeID'], how='inner')
print(merged_df.head())
# Out:
#                     activityID             startTime+GST  \
# 0  2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 1  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 2  2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 3  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 4  2024-11-05T00:09:00-CME-001 2024-11-05 00:09:00+00:00
#
#                 CME_ActivityID                        cmeID  \
# 0  2024-11-03T15:13:00-FLR-001  2024-11-03T15:27:00-CME-001
# 1  2024-11-04T01:05:00-FLR-001  2024-11-04T01:36:00-CME-001
# 2  2024-11-04T11:46:00-FLR-001  2024-11-04T13:23:00-CME-001
# 3  2024-11-04T15:26:00-FLR-001  2024-11-04T17:24:00-CME-001
# 4  2024-11-07T14:29:00-IPS-001  2024-11-05T00:09:00-CME-001
#
#               startTime+cme               GST_ActivityID
# 0 2024-11-03 15:27:00+00:00  2024-11-03T15:13:00-FLR-001
# 1 2024-11-04 01:36:00+00:00  2024-11-04T01:05:00-FLR-001
# 2 2024-11-04 13:23:00+00:00  2024-11-04T11:46:00-FLR-001
# 3 2024-11-04 17:24:00+00:00  2024-11-04T15:26:00-FLR-001
# 4 2024-11-05 00:09:00+00:00  2024-11-07T14:29:00-IPS-001

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst
display(merged_df.head())
# Out:
#                     activityID             startTime+GST  \
# 0  2024-11-03T15:27:00-CME-001 2024-11-03 15:27:00+00:00
# 1  2024-11-04T01:36:00-CME-001 2024-11-04 01:36:00+00:00
# 2  2024-11-04T13:23:00-CME-001 2024-11-04 13:23:00+00:00
# 3  2024-11-04T17:24:00-CME-001 2024-11-04 17:24:00+00:00
# 4  2024-11-05T00:09:00-CME-001 2024-11-05 00:09:00+00:00
#
#                 CME_ActivityID                        cmeID  \
# 0  2024-11-03T15:13:00-FLR-001  2024-11-03T15:27:00-CME-001
# 1  2024-11-04T01:05:00-FLR-001  2024-11-04T01:36:00-CME-001
# 2  2024-11-04T11:46:00-FLR-001  2024-11-04T13:23:00-CME-001
# 3  2024-11-04T15:26:00-FLR-001  2024-11-04T17:24:00-CME-001
# 4  2024-11-07T14:29:00-IPS-001  2024-11-05T00:09:00-CME-001
#
#               startTime+cme               GST_ActivityID timeDiff
# 0 2024-11-03 15:27:00+00:00  2024-11-03T15:13:00-FLR-001   0 days
# 1 2024-11-04 01:36:00+00:00  2024-11-04T01:05:00-FLR-001   0 days
# 2 2024-11-04 13:23:00+00:00  2024-11-04T11:46:00-FLR-001   0 days
# 3 2024-11-04 17:24:00+00:00  2024-11-04T15:26:00-FLR-001   0 days
# 4 2024-11-05 00:09:00+00:00  2024-11-07T14:29:00-IPS-001   0 days

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
print(merged_df.columns)
# Out:
# Index(['activityID', 'startTime+GST', 'CME_ActivityID', 'cmeID',
#        'startTime+cme', 'GST_ActivityID'],
#       dtype='object')

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.
merged_df['timeDiff'] = merged_df['startTime+GST'] - merged_df['startTime+cme']
print(merged_df[['startTime+GST', 'startTime+cme', 'timeDiff']].head())
# Out:
#               startTime+GST             startTime+cme timeDiff
# 0 2024-11-03 15:27:00+00:00 2024-11-03 15:27:00+00:00   0 days
# 1 2024-11-04 01:36:00+00:00 2024-11-04 01:36:00+00:00   0 days
# 2 2024-11-04 13:23:00+00:00 2024-11-04 13:23:00+00:00   0 days
# 3 2024-11-04 17:24:00+00:00 2024-11-04 17:24:00+00:00   0 days
# 4 2024-11-05 00:09:00+00:00 2024-11-05 00:09:00+00:00   0 days

# %%
# Use describe() to compute the mean and median time 
time_diff_stats = merged_df['timeDiff'].describe()
# that it takes for a CME to cause a GST. 
mean_time_diff = time_diff_stats['mean']
median_time_diff = merged_df['timeDiff'].median()
print(f"Mean time difference: {mean_time_diff}")
print(f"Median time difference: {mean_time_diff}")
# Out:
# Mean time difference: 0 days 00:00:00
# Median time difference: 0 days 00:00:00

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
merged_df.to_csv('merged_data.csv, index=False')
